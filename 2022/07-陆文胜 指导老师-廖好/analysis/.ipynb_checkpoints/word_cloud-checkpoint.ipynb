# %%
import numpy as np
import pandas as pd
import wordcloud

# %%
path = "../ERCP_C_City4_log/29:08:10:46:40/explanation/"

# %%
# itemid, label, generated_review
itemid_label = pd.read_csv(path+"item_label.txt",sep="\t",header=None)
# itemid_label = pd.read_csv("../ERCP_C_City4_log/29:08:10:46:40/explanation/item_label.txt",sep="\t",header=None)

# %%
itemid_label.columns = ['itemid', 'label']

# %%
itemid_label = itemid_label.sort_values(by='itemid', ascending=True)

# %%
itemid_label = itemid_label.reset_index()

# %%
itemid_label =  itemid_label[['itemid','label']]

# %%
itemid_label
# Out:
#      itemid  label
# 0         0      1
# 1         1      0
# 2         2      1
# 3         3      0
# 4         4      0
# ..      ...    ...
# 741     748      1
# 742     749      0
# 743     750      0
# 744     751      0
# 745     752      0
#
# [746 rows x 2 columns]

# %%
# data = pd.concat(frame,axis = 1)
# data.columns=['itemid','label']
# data = data.drop_duplicates()

# %%
nums =itemid_label.shape[0]
review = []
for i in range(0,nums):
    rev = pd.read_csv(path+"gen_review."+str(i)+".txt",sep="\n",header=None)
    line = rev[0][0]
    review.append(line)

# %%
itemid_review = pd.DataFrame(review)

# %%
itemid_review.columns = ['review']

# %%
frame = [itemid_label, itemid_review]

# %%
itemid_label_review = pd.concat(frame,axis = 1)

# %%
df = itemid_label_review.groupby(by=['label'])

# %%
df0 = df.get_group(0)
df1 = df.get_group(1)

# %%
###
stringReview = ''
for index, row in df0.iterrows():
    stringReview += row['review']

# %%
wc = wordcloud.WordCloud(font_path="msyh.ttc",
                         width = 1000,
                         height = 700,
                         background_color='white',
                         max_words=100)
# msyh.ttc电脑本地字体，写可以写成绝对路径
wc.generate(stringReview) # 加载词云文本
wc.to_file("City_4.png") # 保存词云文件
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-188-d8fb0c47a017> in <module>
#       5                          max_words=100)
#       6 # msyh.ttc电脑本地字体，写可以写成绝对路径
# ----> 7 wc.generate(stringReview) # 加载词云文本
#       8 wc.to_file("City_4.png") # 保存词云文件
#
# ~/miniconda3/lib/python3.7/site-packages/wordcloud/wordcloud.py in generate(self, text)
#     630         self
#     631         """
# --> 632         return self.generate_from_text(text)
#     633
#     634     def _check_generated(self):
#
# ~/miniconda3/lib/python3.7/site-packages/wordcloud/wordcloud.py in generate_from_text(self, text)
#     612         """
#     613         words = self.process_text(text)
# --> 614         self.generate_from_frequencies(words)
#     615         return self
#     616
#
# ~/miniconda3/lib/python3.7/site-packages/wordcloud/wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     445             else:
#     446                 self.generate_from_frequencies(dict(frequencies[:2]),
# --> 447                                                max_font_size=self.height)
#     448                 # find font sizes
#     449                 sizes = [x[1] for x in self.layout_]
#
# ~/miniconda3/lib/python3.7/site-packages/wordcloud/wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     494             while True:
#     495                 # try to find a position
# --> 496                 font = ImageFont.truetype(self.font_path, font_size)
#     497                 # transpose font optionally
#     498                 transposed_font = ImageFont.TransposedFont(
#
# ~/miniconda3/lib/python3.7/site-packages/PIL/ImageFont.py in truetype(font, size, index, encoding, layout_engine)
#     278
#     279     try:
# --> 280         return FreeTypeFont(font, size, index, encoding, layout_engine)
#     281     except IOError:
#     282         ttf_filename = os.path.basename(font)
#
# ~/miniconda3/lib/python3.7/site-packages/PIL/ImageFont.py in __init__(self, font, size, index, encoding, layout_engine)
#     143         if isPath(font):
#     144             self.font = core.getfont(font, size, index, encoding,
# --> 145                                      layout_engine=layout_engine)
#     146         else:
#     147             self.font_bytes = font.read()
#
# OSError: cannot open resource

# %%
wc = wordcloud.WordCloud(font_path="msyh.ttc",
                         width = 1000,
                         height = 700,
                         background_color='white',
                         max_words=100,stopwords=s)
# msyh.ttc电脑本地字体，写可以写成绝对路径
wc.generate(text) # 加载词云文本
wc.to_file("李焕英1.png") # 保存词云文件
# Out:
# 0
#      itemid  label                                             review
# 1         1      0  环境 不错 ， 每次 都 没有 机会 去 吃 ， 谢谢 。 3333333 菜 的 味道 不...
# 3         3      0  今天 中午 去 吃 过 脚底 摩 68 元 ， 仲食佐 个 送 的 套餐 ， 两个 人 一齐...
# 4         4      0  — — — — — — — — — — — — — — — — — — — — — — — ...
# 5         5      0  @ 心泉 之 公司 玩 ， 终于 就 在 公司 一起 ， 这 餐饭 从 19 20 22 ，...
# 6         6      0  生日 的 尾牙 去 白虎 吃 BUFFET , 网上 评论 非常 旺 , 行前 确实 不错 ...
# ..      ...    ...                                                ...
# 740     747      0  去 了 都 会 去 吃 ， 点 了 一个 炸豆腐 套餐 ， 味道 同仙仔 有 得 辉 ； 还...
# 742     749      0  人气 还 不错 ， 味道 还 不错 。 。 。 。 。 。 。 。 。 。 。 。 。 。 ...
# 743     750      0  半年前 在 网站 西关 风情 的 摄影 比赛 上 侥幸 获得 了 一个 一等奖 ， 奖品 是...
# 744     751      0  呢 间 最 好吃 的 ， 有 D 58 味 ， 好好 味 ， 够 钁 气 都 看不到 ， 呃...
# 745     752      0  看 了 点评 网 的 试食 啊 ， 这次 看 了 一圈 ， 所以 特意 挑 了 几样 试食 ...
#
# [533 rows x 3 columns]
#
#
# 1
#      itemid  label                                             review
# 0         0      1  喝完 早茶 ， 老师 顺便 去 吃 步行 的 仁信 。 步行 去 流行 前线 时 ， 顺便去...
# 2         2      1  呢 间 ， 原来 唔 显眼 ！ 亲戚 订 佐位 係 二楼 ， 上到 去 买 佐位 围 ！ 上...
# 9         9      1  餐厅 不大 不大 的 餐厅 是 试业 ， 尤其 是 景观 一流 ， 尤其 是 景观 一流 。...
# 12       12      1  陶园 ， 还 不错 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 ...
# 19       19      1  一直 好久没 到 pizzahut 吃 了 ， 近期 出 了 。 近期 非常 好 ， 出品 ...
# ..      ...    ...                                                ...
# 733     740      1  每次 都 是 这里 的 常客 , 每周 这里 的 常客 . 每周 玩 的 时候 都 是 这里...
# 735     742      1  我 来 吃 吃 的 ， 阿妈 推荐 ， 新开 的 茶市 ， 都 是 有 一种 好吃 的 。 ...
# 736     743      1  跟 朋友 出去玩 就 住 对面 就 去 喝 早茶 ， 去 的 时候 就 忍不住 去 试试 ，...
# 737     744      1  这 是 我 吃 过 最贵 的 盒饭 哦 ， 160 块 ， 但是 加 着 加 着 加 了 的...
# 741     748      1  广州市区 的 萨莉亚 都 人山人海 ， 番禺 繁华 店 由于 是 新开 的 暂时 人流 还 ...
#
# [213 rows x 3 columns]

# %%
df = df.to_frame()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-171-0acfea0828d6> in <module>
# ----> 1 df = df.to_frame()
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     564
#     565         raise AttributeError(
# --> 566             "%r object has no attribute %r" % (type(self).__name__, attr)
#     567         )
#     568
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'to_frame'

# %%
grouped  = itemid_label_review.groupby('itemid')

# %%
for name,group in grouped:
    print (group)
    print ('\n')
# Out:
#    itemid  label                                             review
# 0       0      1  喝完 早茶 ， 老师 顺便 去 吃 步行 的 仁信 。 步行 去 流行 前线 时 ， 顺便去...
#
#
#    itemid  label                                             review
# 1       1      0  环境 不错 ， 每次 都 没有 机会 去 吃 ， 谢谢 。 3333333 菜 的 味道 不...
#
#
#    itemid  label                                             review
# 2       2      1  呢 间 ， 原来 唔 显眼 ！ 亲戚 订 佐位 係 二楼 ， 上到 去 买 佐位 围 ！ 上...
#
#
#    itemid  label                                             review
# 3       3      0  今天 中午 去 吃 过 脚底 摩 68 元 ， 仲食佐 个 送 的 套餐 ， 两个 人 一齐...
#
#
#    itemid  label                                             review
# 4       4      0  — — — — — — — — — — — — — — — — — — — — — — — ...
#
#
#    itemid  label                                             review
# 5       5      0  @ 心泉 之 公司 玩 ， 终于 就 在 公司 一起 ， 这 餐饭 从 19 20 22 ，...
#
#
#    itemid  label                                             review
# 6       6      0  生日 的 尾牙 去 白虎 吃 BUFFET , 网上 评论 非常 旺 , 行前 确实 不错 ...
#
#
#    itemid  label                                             review
# 7       7      0  每次 都 是 爱 去 去 的 ， 可见 体育 西 的 活动 稀罕 了 ， 现在 搬家 到 体...
#
#
#    itemid  label                                             review
# 8       8      0  要 了 份 商务 午餐 套餐 ： 欧式 培根 炒饭 和 尊享 奶茶 （ 28 ） 炒饭 有点...
#
#
#    itemid  label                                             review
# 9       9      1  餐厅 不大 不大 的 餐厅 是 试业 ， 尤其 是 景观 一流 ， 尤其 是 景观 一流 。...
#
#
#     itemid  label                                             review
# 10      10      0  4 个人 去 食 , 一共 个人 去 吃 , 一共 吃 三百 几 多 , 所以 吃 左 就 ...
#
#
#     itemid  label                                             review
# 11      11      0  睇 完 德国 对 阿根廷 ， 从东山 黎 到 呢 度 吃宵夜 ， 成条 宝业 路 都 好旺 ...
#
#
#     itemid  label                                             review
# 12      12      1  陶园 ， 还 不错 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 ...
#
#
#     itemid  label                                             review
# 13      13      0  酸菜鱼 还 可以 ， 但是 也 不算什么 特色 ， 但凡 吃 这种 菜系 的 饭馆 ， 都 ...
#
#
#     itemid  label                                             review
# 14      14      0  环境 不错 ， 我 都 是 这里 的 最难 那家 的 最难 喝 的 ， 印象 满满的 ， 但...
#
#
#     itemid  label                                             review
# 15      15      0  在 广州 的 时候 去 吃 年饭 ， 点 了 一个 杨枝 甘露 ， 味道 很 不错 ， 印象...
#
#
#     itemid  label                                             review
# 16      16      0  虾饺 超大 呀 ， 服务 也好 ， 服务 也好 。 鱼片 粥 也 不错 ， 买单 超慢 的 ...
#
#
#     itemid  label                                             review
# 17      17      0  广州 酒家 的 老字号 ， 总店 比较 陈旧 就 喝 早茶 了 。 天河 那家 搞 婚庆 的...
#
#
#     itemid  label                                             review
# 18      18      0  这里 的 自助餐 场 ， 超级 大 ， 热食 、 烧烤 、 烧烤 、 烧烤 、 烧烤 、 烧...
#
#
#     itemid  label                                             review
# 19      19      1  一直 好久没 到 pizzahut 吃 了 ， 近期 出 了 。 近期 非常 好 ， 出品 ...
#
#
#     itemid  label                                             review
# 20      20      1  去过 过 一次 ， 公司 的 时候 经常 来 这里 吃饭 ， 环境 还 不错 ， 环境 还 ...
#
#
#     itemid  label                                             review
# 21      21      0  两个 人 去 食 ， 两条 友 ， 一个 58 蚊 ， 好似 系 芒果 大碗 ， d 嘢 都...
#
#
#     itemid  label                                             review
# 22      22      0  4 层楼 ， 这里 的 三文鱼 还是 挺 多 的 ， 味道 很 好 ， 地道 的 环境 很 ...
#
#
#     itemid  label                                             review
# 23      23      0  环境 不错 ， 没有 早茶 ， 百 吃 的 土腥味 。 。 。 。 。 。 。 。 。 。 ...
#
#
#     itemid  label                                             review
# 24      24      1  环境 不错 ， 服务 也 不错 。 老师 老师 去 的 缘故 ， 一行 9 人 ， 可见 其...
#
#
#     itemid  label                                             review
# 25      25      1  源 记开 了 好多年 了 ， 但 环境 始终如一 地好 。 环境 不错 ， 恰到好处 ， 很...
#
#
#     itemid  label                                             review
# 26      26      1  澳门街 的 韩式 冬季 当 当锅 。 六个 人 去 的 ， 在 楼下 的 两张 券 。 五点...
#
#
#     itemid  label                                             review
# 27      27      1  单位 宴请 的 火锅 ， 风景 不错 ， 风景 嘛 ， 超大 了 些 超大 ， 风景 无限 ...
#
#
#     itemid  label                                             review
# 28      28      1  打印 了 点评 网 的 39 元 套餐 尝尝鲜 。 晚上 7 点 多 去 到 ， 一楼 楼顶...
#
#
#     itemid  label                                             review
# 29      29      0  周六 早上 去 在 北京路 网上 花 上 这家 店 后 就 在 北京路 走过 去 的 时候 ...
#
#
#     itemid  label                                             review
# 30      30      0  周五 中午 去 去 吃 ， 人不多 ， 环境 还 不错 ， 上餐 很快 ， 服务员 迷迷糊糊...
#
#
#     itemid  label                                             review
# 31      31      0  在 广州 的 时候 真的 很 不错 。 这里 的 味道 很 不错 ， 值得 推荐 。 这里 ...
#
#
#     itemid  label                                             review
# 32      32      1  只不过 想来 吃 个 快餐 而已 ， 点知 都 是 变作 慢餐 。 地方 很 窄 ， 服务员...
#
#
#     itemid  label                                             review
# 33      33      0  朋友 开车 带 着 我们 从 广州 出发 ， 一路 开 了 这儿 ， 就 在 天河 出发 ，...
#
#
#     itemid  label                                             review
# 34      34      0  周末 familyday ， 中午 照例 去 去 公认 抵食 夹 大件 的 大城 小厨 ， ...
#
#
#     itemid  label                                             review
# 35      35      1  每次 去 天河城 ， 都 会 忍不住 去 他家 。 他家 的 日式 轻 芝士 蛋糕 味道 不...
#
#
#     itemid  label                                             review
# 36      36      0  环境 很 一般 ， 锅子 很 大量 很多 ， 空心菜 比较 安静 ， 锅子 也 不行 。 最...
#
#
#     itemid  label                                             review
# 37      37      0  西江 骨 真的 不错 很爽 ~ 环境 很 重 ， 不过 味道 不错 ， 服务 还是 不错 的...
#
#
#     itemid  label                                             review
# 38      38      1  出差 来 的 时候 在 这里 吃 过 一次 ， 还 不错 哦 ， 挑 了 室外 的 位置 ，...
#
#
#     itemid  label                                             review
# 39      39      0  最 歡 喜 佢 嘅 腸 仔 牛角 包 嘅 ~ ~ ~ ~ ~ D 包 , 腸仔 燒得 好好 ...
#
#
#     itemid  label                                             review
# 40      40      0  去过 两次 ， 第一次 觉得很有 新鲜感 ， 第二次 就 去 了 ， 就 去 的 时候 经常...
#
#
#     itemid  label                                             review
# 41      41      0  这家 店 是 新开 的 ， 请客 的 味道 都 不错 ， 不膻 ， 不腻 ， 里面 的 味道...
#
#
#     itemid  label                                             review
# 42      42      0  不错 的 快餐店 我 在 这里 吃 寸土寸金 的 地方 也 不 例外 ， 所以 也 有 卫生...
#
#
#     itemid  label                                             review
# 43      43      0  本来 二条 友 去 吃 陶然 会架 ， 去 知来 细 罗 。 话 吾 错 罗 。 唯有 去 ...
#
#
#     itemid  label                                             review
# 44      44      1  被 朋友 欺骗 的 儿童 超值 , 但 竟然 一直 一直 去 试试 , 于是 人 多 , 但...
#
#
#     itemid  label                                             review
# 45      45      0  因为 在 广州 附近 ， 所以 却是 却是 却是 却是 却是 却是 却是 却是 却是 却是 ...
#
#
#     itemid  label                                             review
# 46      46      0  因为 拿到 广告 纸话 午市 自助 火锅 ￥ 39 / 位 ， 汤底 另计 ￥ 15 ， 味...
#
#
#     itemid  label                                             review
# 47      47      1  这家 仙踪 林 的 路上 找 ， 交通 还 算 可以 。 环境 还 不错 ， 交通 也 比较...
#
#
#     itemid  label                                             review
# 48      48      0  好 早就 知道 八百 膳 吃 日本料理 精品 啦 ， 就 想到 广州 好贵 。 占地 好 大...
#
#
#     itemid  label                                             review
# 49      49      0  两个 人 去 吃 ， 自助 了 自助 自助 的 自助 套餐 ， 锅底 很 好吃 ， 锅底 味...
#
#
#     itemid  label                                             review
# 50      50      0  好久没 去 的 ， 点 了 个 松子 鱼 ， 味道 很 好 ， 味道 还 不错 ， 就是 值...
#
#
#     itemid  label                                             review
# 51      51      0  红烧 乳鸽 20 ， 麻麻 地 清香 鸽 20 ， 好 了 红烧 南乳 炒新 垦 藕片 ， ...
#
#
#     itemid  label                                             review
# 52      52      1  上午 业务学习 ， 中午 领导 说 慰劳 大家 周末 加班 辛苦 ， 所以 请 吃饭 ， 选...
#
#
#     itemid  label                                             review
# 53      53      0  朋友 请吃 早茶 ， 环境 气派 ， 服务周到 ， 一直 殷勤 加茶 ， 毕竟 要 加收 服...
#
#
#     itemid  label                                             review
# 54      54      1  这家 店 是 新开 的 ， 新派 的 装修 ， 灯光 明亮 ， 六点 的 时候 就 坐满 空...
#
#
#     itemid  label                                            review
# 55      55      1  环境 很 好 ， 出品 也 不错 。 酸菜鱼 也 很 不错 ， 并 没有 想象 中 的 火爆 。
#
#
#     itemid  label                                             review
# 56      56      0  参加 某 网站 的 团购 活动 ， 原价 五百多 的 ， 据说 只要 一百多 就 可以 了 ...
#
#
#     itemid  label                                             review
# 57      57      0  上次 写 了 乳鸽 排 第一 的 沙面 兰桂坊 ， 糖 很少 ， 糖 很少 ， 但是 侨 美...
#
#
#     itemid  label                                             review
# 58      58      1  同事 们 都 系 加州红 好 耐 吃 ， 但 他 去 得 可以 去过 ， 但 一直 一直 去...
#
#
#     itemid  label                                             review
# 59      59      1  周五 在 公司 附近 ， 所以 找 了 一顿 了 ~ ~ 点 了 份箱 压 鱼 和 石锅 饭...
#
#
#     itemid  label                                             review
# 60      60      0  为了 一睹 荔枝 涌 的 风貌 ， 特意 在 张 记订 台 的 风貌 ， 观看 ！ 羊肉 煲...
#
#
#     itemid  label                                             review
# 61      61      0  太古 汇 既 呢间 太平洋 咖啡 真系 好 舒服 ， WIFI 好 好 舒服 ， WIFI ...
#
#
#     itemid  label                                             review
# 62      62      1  这间 店 开 了 一次 ， 去 了 万国 之后 就 去 吃 ， 去 了 一圈 。 点 了 一...
#
#
#     itemid  label                                             review
# 63      63      1  从来未 系 我 带 过 西饼 的 店铺 , 其实 卖字 甘 , 写住 它 买 过 5 多 ,...
#
#
#     itemid  label                                             review
# 64      64      0  在 文明 路 逛街 ， 就 会 煮 苏记 ， 门口 摆 着 炉灶 ， 里面 煮 着 牛杂 、...
#
#
#     itemid  label                                             review
# 65      65      0  几年 前 已经 知道 秦妈 秦妈 动感 动感 久 ， 想去 的 时候 终于 说 秦妈 些 动...
#
#
#     itemid  label                                             review
# 66      66      1  很多很多 很多很多 朋友 去 的 时候 去 的 时候 去 的 时候 去 的 时候 去 的 时...
#
#
#     itemid  label                                             review
# 67      67      1  老妈 怕辣 不让 点 水 煮 系列 和 酸菜鱼 ， 只好 退而求 次 向 小炒 类 下手 ，...
#
#
#     itemid  label                                             review
# 68      68      1  一个 人 去 的 ， 新派 的 料理 都 不错 ， 人 多 ， 没有 人 等 。 要 了 很...
#
#
#     itemid  label                                             review
# 69      69      1  爱都 一街 附近 新 开张 ， 去过 派 路 餐厅 新 开张 ， 所以 由于 勤快 的 派 ...
#
#
#     itemid  label                                             review
# 70      70      0  到 萬達 廣場 去 逛街 , 這次 我們 兩個 人 吃 飯 , 這次 我們 兩個 人 吃 飯...
#
#
#     itemid  label                                             review
# 71      71      0  团购 的 套餐 ， 38 元 两个 人 ， 38 元 的 ， 当时 不 愿意 去 的 国人 ...
#
#
#     itemid  label                                             review
# 72      72      1  最 喜欢 这里 的 出品 ， 不 知道 是不是 2 人 去 ， 可以 去 光顾 时 不 知道...
#
#
#     itemid  label                                             review
# 73      73      1  最 喜欢 这里 的 芝士 蛋糕 ， 味道 还 可以 ， 不过 也 没有 想象 中 的 可乐 ...
#
#
#     itemid  label                                             review
# 74      74      1  住 在 番禺 的 楼盘 ， 因此 山塘 饭店 从刚 开到 找 ， 因此 山塘 饭店 从刚 开...
#
#
#     itemid  label                                           review
# 75      75      0  这里 的 环境 还是 不错 的 , 味道 也 不错 , 但胜 有 半斤 多 一个 缘故 吧 ,
#
#
#     itemid  label                                             review
# 76      76      0  好 耐 都 系 好 耐 ~ ~ ~ 寿司 同 寿司 都 无 咩 选择 ~ ~ ~ 寿司 都 ...
#
#
#     itemid  label                                             review
# 77      77      1  环境 一如既往 的 ， 味道 一如既往 的 ， 但是 可可 更胜一筹 。 炸豆腐 就是 一如...
#
#
#     itemid  label                                             review
# 78      78      0  这里 的 牛丸 比较 多 ， 环境 很 好 ， 环境 很 好 ， 不过 环境 不错 ， 每次...
#
#
#     itemid  label                                             review
# 79      79      0  这家 江南 大道 的 皇后 饼店 地理位置 就 很 好 ， 江南西 上 江南西 的 时候 就...
#
#
#     itemid  label                                             review
# 80      80      0  今晚 系统 有家 公司 周年 庆典 ， 在 万寿宫 四楼 包 了 个 大厅 ， 摆 了 十几...
#
#
#     itemid  label                                             review
# 81      81      0  朋友 特地 路过 的 一间 , 有个 烧 的 乳鸽 , 开业 的 两碗 味 , 有个 15 ...
#
#
#     itemid  label                                             review
# 82      82      0  因为 在 孤近 . 经常 会去 了 . 非常 好吃 . 三文鱼 刺身 也 不错 . 三文鱼 ...
#
#
#     itemid  label                                             review
# 83      83      1  这里 的 第一顿 式 uncle ， 第一次 吃 了 uncle ， 就 发现 。 这里 的...
#
#
#     itemid  label                                             review
# 84      84      0  我 去 饭团 ， 经常 去 饭团 ， 要 等位 ， 自助餐 味道 一般 ， 一般 的 男士 ...
#
#
#     itemid  label                                             review
# 85      85      0  一家 点评 的 老字号 ， 高大 的 屋顶 ， 气度 恢弘 。 高大 的 屋顶 ， 气度 恢...
#
#
#     itemid  label                                             review
# 86      86      0  环境 很 好 ， 味道 很 不错 ， 法式 法式 芝麻糊 ， 香茅 虾 、 香茅 蒸 、 芋...
#
#
#     itemid  label                                             review
# 87      87      0  隔 了 点评 十年 都 有 海南 优惠券 ， 文昌鸡 还是 记忆 中 那么 太 多 。 我们...
#
#
#     itemid  label                                             review
# 88      88      1  呢 间 最 耐 去 吃 ， 出发 完 做定 功课 找 ， 出发 间 做定 功课 找 ， 见 ...
#
#
#     itemid  label                                             review
# 89      89      0  环境 不错 ， 碟头 很小 很小 ， 碟头 很小 很小 ， 碟头 很小 很小 ， 碟头 很小...
#
#
#     itemid  label                                             review
# 90      90      1  上年 就 记得 呢 间 广州市 最 出名 的 煲仔饭 . 唯有 再 去 碰运气 , 终于 找...
#
#
#     itemid  label                                             review
# 91      91      1  非常 喜欢 豉油 皇鹅 肠 ， 非常 好吃 ， 酸辣粉 的 味道 都 不错 ， 最 咸 了 ...
#
#
#     itemid  label                                             review
# 92      92      0  很 喜欢 的 一家 湘菜馆 ， 味道 很 不错 的 选择 ， 味道 也 不错 的 选择 ~ ...
#
#
#     itemid  label                                             review
# 93      93      1  一个 小 快餐店 ， 第一次 吃 班 戟 ， 味道 还 不错 。 。 。 。 。 。 。 。...
#
#
#     itemid  label                                             review
# 94      94      1  餐 前 小食 5 元 一份 ， 有 三份 ， 紫薯 ， 豆腐 角 ， 芥末 黑木耳 豆腐 一...
#
#
#     itemid  label                                             review
# 95      96      0  去过 过 的 ， 48 蚊 / 蚊 / 蚊 / 蚊 / 蚊 / 蚊 / 蚊 / 蚊 / 位 ...
#
#
#     itemid  label                                             review
# 96      97      0  之前 去 了 ， 觉得 不 多 的 一家 选择 ， 味道 很 好 ， 环境 还 不错 ， 分...
#
#
#     itemid  label                                             review
# 97      98      0  说实话 , 味道 不错 , 就是 小小的 寿司 的 味道 也 不错 , 应该 是 外带 的 ...
#
#
#     itemid  label                                  review
# 98      99      0  南海 渔村 出品 就 真 系 吾 错 ， 我 就 系 这里 的 利害 啦 。
#
#
#     itemid  label                                             review
# 99     100      0  师姐 们 毕业 请 点 了 点 ， 顺德 菜 的 质量 也 不错 ， 还有 哪个 菜 也 很...
#
#
#      itemid  label                                             review
# 100     101      1  是 广州 的 三文鱼 很 好吃 的 ， 但是 味道 也 很 好 ， 猪脚 烧 的 很 入味 ...
#
#
#      itemid  label                                             review
# 101     102      0  这里 的 香辣虾 ， 通常 都 是 女子 去 ， 一起 的 香辣虾 ， 香辣虾 ， 香辣虾 ...
#
#
#      itemid  label                                             review
# 102     103      0  刚读 大学 的 时候 就 来 过 这 一家 老店 ， 买 一个 一排 之后 就 一发 不可收...
#
#
#      itemid  label                                             review
# 103     104      0  呢 间 表妹 靓点 的 介绍 , 在 海珠 广场 唱 完 K , 在 海珠 广场 唱 完 K...
#
#
#      itemid  label                                             review
# 104     105      1  环境 很 有 格调 ， 老 西关 的 装修 ， 最高 一层 更好 。 菱角 、 艾 糍 、 ...
#
#
#      itemid  label                                             review
# 105     106      0  哥哥 和 同事 看 过 电影 ， 没 他 的 这家 店 来 吃 的 ， 结果 去 的 时候 ...
#
#
#      itemid  label                                             review
# 106     107      0  培训 住 的 · · · 自助 自助 两天 的 自助 · · 自助 午餐 · · 自助 午餐...
#
#
#      itemid  label                                             review
# 107     108      0  在 附近 做 了 一个 团购 按摩 , 按摩师 就 以 东北 物美价廉 , 按摩师 的 2 ...
#
#
#      itemid  label                                             review
# 108     109      0  昨天 去 住 的 ， 顺便 顺便 去 到 抹 章鱼 套餐 ， 他家 的 日式 轻 粥 粥 ，...
#
#
#      itemid  label                                             review
# 109     110      0  在 陈岗 的 时候 经常 经常 在 这里 吃 了 都 很 不错 。 这里 的 出品 很 不错...
#
#
#      itemid  label                                             review
# 110     111      0  睇 左 南方 台 的 美食 节目 介绍 冒名 而 去 ， 睇 完 垃圾 下 下 ， 成日 都...
#
#
#      itemid  label                                             review
# 111     112      0  超差 既 甜品店 ， 唔 知 点解 好多 人 去 吃 ， 点知 人地 开会 ， 点知 唔 错...
#
#
#      itemid  label                                             review
# 112     113      0  第一次 吃 千味 涮 ， 才 知道 是 一家 店 ， 很 有 特色 。 点 了 一个 特价 ...
#
#
#      itemid  label                                             review
# 113     114      0  特登 坐车 过来 食碗 大杂烩 ， 没 想像中 噤好食 ， 首先 汤 真是 好 清 ， 有 ...
#
#
#      itemid  label                                             review
# 114     115      1  ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ 【 森意 美食 （ 福 中路 ） 】 ∷ ∷ ∷ ∷...
#
#
#      itemid  label                                             review
# 115     116      0  这里 的 炖品 做 得 非常 好 ， 在 广州 物价飞涨 的 年代 。 环境 也 不错 ， ...
#
#
#      itemid  label                                             review
# 116     117      1  喜欢 中大 的 ， 经常 路过 ， 经常 路过 ， 经常 路过 ， 经常 路过 ， 经常 路...
#
#
#      itemid  label                                             review
# 117     118      1  元旦 那天 ， 同 外父 外母 一家人 从 烈士陵园 出来 ， 正 准备 前往 食店 众多 ...
#
#
#      itemid  label                                             review
# 118     119      0  中午 最 想 去 ， 有时 中午 去 吃 两三次 ， 有时 就要 乖乖 前 时间 book ...
#
#
#      itemid  label                                             review
# 119     120      0  以前 打算 去 过 ， 番黎 唔 记得 写 个 桂芳 ， 衣家 都 话 话 七七八八 啦 ，...
#
#
#      itemid  label                                             review
# 120     121      0  环境 新装修 ， 空间 多 ， 空间 多 ， 空间 多 ， 空间 多 ， 空间 多 ， 空间...
#
#
#      itemid  label                                             review
# 121     122      0  偶然 在 这里 吃饭 ， 一晚 人 在 这里 吃饭 ， 一晚 人 在 这里 的 餐厅 桌椅 ...
#
#
#      itemid  label                                             review
# 122     123      0  下午茶 时段 叫 到 公司 的 外卖 ， 送到 高德 置 地 叫 了 4 种 口味 的 ， ...
#
#
#      itemid  label                                             review
# 123     124      0  看到 点评 慕名而来 ， 离家 不远 ， 因为 司机 方向感 欠佳 ， 东风路 掉头 拐 才...
#
#
#      itemid  label                                             review
# 124     125      0  这里 的 大菜 牌 ， 心里 有 小算盘 ， 椰子 竹丝 鸡 不假思索 ， 鲜奶 炖鸡 倍感...
#
#
#      itemid  label                                             review
# 125     126      1  最近 这里 的 老字号 ， 一次 ， 环境 不错 。 。 。 。 。 。 。 。 。 。 。...
#
#
#      itemid  label                                             review
# 126     127      0  刚 晚饭时间 人 去 ， 没顺 人 ， 环境 非常 差 ， 炸酱 伊面太 咸 了 ， 猪肠 ...
#
#
#      itemid  label                                             review
# 127     128      0  第一次 吃 法国 餐 ， 第一次 去 法国 法国 餐 法国 法国 餐 ， 落班 时分 法国 ...
#
#
#      itemid  label                                             review
# 128     129      1  之前 之前 都 系 蒙地卡罗 ， 之前 都 系 蒙地卡罗 ， 之前 都 系 蒙地卡罗 ， 所...
#
#
#      itemid  label                                             review
# 129     130      1  上 了 6 楼 ， 去 的 时候 晚 了 ， 就 去 了 。 同行 的 时候 去 了 ， 就...
#
#
#      itemid  label                                             review
# 130     131      0  人 唔 多 ， 但 电梯间 多 。 服务态度 还 可以 ， 但 数 不出 特别 好吃 的 ~...
#
#
#      itemid  label                                             review
# 131     132      0  — — — — — — — — — 【 囍 囍 酒家 （ 广州 文化 假日酒店 ） 】 — ...
#
#
#      itemid  label                                             review
# 132     133      0  广州 这样 的 菜 ， 真的 是 广州 的 菜 ， 简简单单 的 味道 还是 很 不错 的 ...
#
#
#      itemid  label                                             review
# 133     134      1  今日 系名 盛 广场 楼下 接到 传单 ， 但 接到 传单 ， 今日 就 北京路 呢 间 。...
#
#
#      itemid  label                                             review
# 134     135      0  几乎 永远 人 多 到 爆 ， 即使 夏天 的 时候 都 会 等位 ， 总是 有 见缝插针 ...
#
#
#      itemid  label                                             review
# 135     136      1  环境 很 好 ， 在 海珠区 南洲 等位 。 点 了 一个 红烧 乳鸽 ， 味道 很 好 ，...
#
#
#      itemid  label                                             review
# 136     137      1  招牌 的 48 元 肶 德国 烧猪 肶 58 元 ， 可惜 是 往常 的 ， 咖喱 捞饭 脆...
#
#
#      itemid  label                                             review
# 137     138      0  一间 开业 很久 的 牛扒 店 , 装修 格调高雅 , 服务员 素养 都 挺 好 , 西餐 ...
#
#
#      itemid  label                                             review
# 138     139      1  每次 都 系 呢 间野 甘多人 等位 ， 可能 系 工作日 ， 所以 系 工作日 ， 所以 ...
#
#
#      itemid  label                                             review
# 139     140      0  和 朋友 再 去 吃 最足 称 的 时候 去 吃 最足 称 这里 的 时候 一度 陪 妈妈 ...
#
#
#      itemid  label                                             review
# 140     141      0  百 吃 不厌 的 煎 饺 ， 一种 是 韭菜 猪肉 ， 一种 是 韭菜 猪肉 ， 一种 是 ...
#
#
#      itemid  label                                             review
# 141     142      0  朋友 天气 干燥 喜爱 上 吃 蔬菜类 ， 吃 了 一个 造型 菜 和 斋 烧鹅 ， 味道 ...
#
#
#      itemid  label                                             review
# 142     143      0  晚上 去 吃 的 ， 晚上 58 蚊 ， 晚上 58 蚊 ， 晚上 58 蚊 ， 晚上 58...
#
#
#      itemid  label                                             review
# 143     144      0  招牌 的 咖喱 蟹 味道 不错 ， 尤其 是 酱汁 配上 伊面 超赞 ， 其他 的 就 没什...
#
#
#      itemid  label                                             review
# 144     145      0  ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ...
#
#
#      itemid  label                                             review
# 145     146      1  位置 确实 偏僻 的 , 凳子 靠背 有的 也 坏 了 , 大块头 的 表弟 坐 的 椅子 ...
#
#
#      itemid  label                                             review
# 146     147      0  点 了 一个 雪山 甘露 ， 味道 不错 ， 点 了 一个 雪山 杨枝 甘露 ， 一个 咖喱...
#
#
#      itemid  label                                            review
# 147     148      0  酸菜鱼 很 好吃 ， 酸菜鱼 也 不 便宜 ， 价格 也 不 便宜 ， 胜 在够 太 多 的 ！
#
#
#      itemid  label                                             review
# 148     149      0  因为 离 公司 近 的 时候 找 了 这间 n 近 饭局 这家 便是 其中 之一 。 土豆泥...
#
#
#      itemid  label                                             review
# 149     150      0  上月底 去 三文鱼 都 变回 ， 原价 三文鱼 、 三文鱼 刺身 都 是 最 新鲜 的 ， ...
#
#
#      itemid  label                                             review
# 150     151      1  跟 朋友 去 的 ， 新派 的 装修 ， 虽然 很 豪华 找 ， 我们 去时 有人 过生日 ...
#
#
#      itemid  label                                             review
# 151     152      0  果晚 系 同个 F 一起 去 的 ， 撞 甘有 78 折 ， 觉得 机不可失 ， 觉得 机不...
#
#
#      itemid  label                                             review
# 152     153      0  在 客村 坐地铁 顺便 顺便 去 吃 ， 买 了 布朗 尼 和 面包 、 布朗 尼 、 布朗...
#
#
#      itemid  label                                             review
# 153     154      0  买 了 杯 碳 烧 奶茶 加黑 钻 , 很 有 三点 一刻 钻 , 还有 三点 也 很好 的...
#
#
#      itemid  label                                             review
# 154     155      0  每次 都 是 为了 这里 吃 茼蒿 ， 因为 本人 酷爱 去 茼蒿 ， 因为 本人 酷爱 去...
#
#
#      itemid  label                                             review
# 155     156      1  和 洋快餐 是 研究 ， 不过 人气 很 旺 ， 因为 人气 也 很 旺 ， 环境 也 很 ...
#
#
#      itemid  label                                             review
# 156     157      0  我 一直 一直 对 海南 菜 和 名声 做 的 ， 对 我 对 广州 的 旅游 餐 的 。 ...
#
#
#      itemid  label                                             review
# 157     158      1  在 2011 年 和 妈妈 一起 的 餐厅 香岛 午餐 ， 尤其 是 我 去 去 吃 午餐 ...
#
#
#      itemid  label                                             review
# 158     159      0  点解 咁 多 嘅 ~ 叫做 表 X 嘅 ~ ~ ~ ~ 价钱 唔 错 ， 价钱 唔 错 ， ...
#
#
#      itemid  label                                             review
# 159     160      0  春节 期间 的 ， 春节 期间 ， 其他 的 春节 软 ， 味道 很 不错 ， 剁 椒 鱼头...
#
#
#      itemid  label                                             review
# 160     161      0  在 附近 很少 会 去 吃 一次 的 · · · 几天 请 去 的 ~ · · 都 是 吃 ...
#
#
#      itemid  label                                             review
# 161     162      1  姑姑 一家 很 喜欢 吃 。 这家 店 很 不错 。 。 。 。 。 。 。 。 。 。 。...
#
#
#      itemid  label                                             review
# 162     163      0  最 好吃 的 芒果 芒果 ， 但 芒果 的 芒果 芒果 ~ ~ 芒果 芒果 的 好吃 ~ ~...
#
#
#      itemid  label                                             review
# 163     164      0  黄鳝 饭 ： 1 斤 米 + 1 斤 米 + 1 斤 米 + 1 斤 米 + 1 斤 黄鳝 ...
#
#
#      itemid  label                                             review
# 164     165      0  以前 在 平安 大戏院 看 戏 前 ， 吃 左 半个 日 ， 以前 来 过 吃 的 ， 以前...
#
#
#      itemid  label                                             review
# 165     166      0  还 不错 ， 人气 停 很大 的 。 环境 还 不错 ， 装修 也 不错 。 装修 停 的 ...
#
#
#      itemid  label                                             review
# 166     167      0  说实话 ， 在 广州 吃 了 半天 ， 找 了 这家 。 这家 的 河南 菜 ， 就 找 了...
#
#
#      itemid  label                                             review
# 167     168      1  在 附近 吃 过 一次 去 的 ， 还 不错 ， 毕竟 是 在 江边 ， 能够 看到 一线 ...
#
#
#      itemid  label                                             review
# 168     169      0  周末 晚上 朋友 去 吃 的 ， 晚上 去 的 时候 去 吃 自助餐 ， 去 的 时候 就 ...
#
#
#      itemid  label                                             review
# 169     170      0  在 这里 的 鲜虾 蟹子 云吞面 就 回味无穷 . 虾子 汤底 好惹 味 , 通常 就 连汤...
#
#
#      itemid  label                                             review
# 170     171      0  在 环市路 ， 这家 店 不贵 了 很多 ， 点 了 擀面 、 哨子 面 、 肉夹馍 、 汤...
#
#
#      itemid  label                                             review
# 171     172      0  以前 系 公寓 住 的 婚宴 ， 觉得 一般 ！ 除 左 一点 都 唔 错 ， 除 左个 鱼...
#
#
#      itemid  label                                             review
# 172     173      0  多年 来 的 ， 偶尔 在 这里 吃 过 一次 。 。 。 。 。 。 。 。 。 。 。 ...
#
#
#      itemid  label                                             review
# 173     174      0  今天 去 了 唐苑 ， 味道 还 不错 ； 坐在 一楼 ， 感觉 灯光 有点 暗 ； 二楼 ...
#
#
#      itemid  label                                             review
# 174     175      1  煲仔饭 应 是 广东 名食 之一 ， 天寒地冻 ， 花 20 分钟 守候 一 煲 热气腾腾 ...
#
#
#      itemid  label                                             review
# 175     176      0  这 是 同事 去 的 ， 同事 想 去 应该 要 scrambledeggs 的 怨念 木有...
#
#
#      itemid  label                                             review
# 176     177      0  团购 去 吃 的 ， 味道 不错 ， 价格 比较 丰富 ， 味道 也 不错 ， 价格 比较 ...
#
#
#      itemid  label                                             review
# 177     178      1  因为 离 公司 近 的 关系 ， 近 段时间 吃 最多 的 时候 都 是 吃 了 最多 的 ...
#
#
#      itemid  label                                             review
# 178     179      1  响 点评 网 到 呢 度 吃饭 ， 但 宜家 呢 间 呢 度 ， 专 登 揾 机会 来 呢 ...
#
#
#      itemid  label                                             review
# 179     180      0  点 了 鱼肚 羹 最后 才 去 的 ， 呵呵 ！ 炸 了 一碗 粥 、 北极 贝 、 鳗鱼 ...
#
#
#      itemid  label                                             review
# 180     181      1  比较 高档 的 火锅 ， 锅底 和 烧鹅 都 是 自制 ， 菜品 的 质量 都 是 自制 ，...
#
#
#      itemid  label                                             review
# 181     182      0  第二次 来 这里 吃 早餐 ， 点 了 皮蛋 煲 （ 28 元 ） ， 九州 拉面 配 粥 ...
#
#
#      itemid  label                                             review
# 182     183      0  上周五 冲着 广发卡 5 折 ， 真的 是 一般 的 。 味道 很 好 ， 但 味道 还 不...
#
#
#      itemid  label                                             review
# 183     184      0  晚上 去 的 ， 性价比 一般 ， 点 了 寿司 蟹 的 味道 都 是 一般 的 ， 鸡味 ...
#
#
#      itemid  label                                             review
# 184     185      0  ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ...
#
#
#      itemid  label                                             review
# 185     186      1  上周四 到 集团 开会 ， 中午 下 大雨 ， 不想 外出 ， 于是 到 楼下 这家 新开 ...
#
#
#      itemid  label                                             review
# 186     187      0  环境 不错 ， 环境 很 好 ， 环境 还 不错 ， 其他 的 菜 也 很 好 ， 环境 很...
#
#
#      itemid  label                                             review
# 187     188      0  怀着 尝 新鲜 的 心情 去 吃 的话 ， 味道 很 好 ， 态度 也 不错 ， 就是 千万...
#
#
#      itemid  label                                             review
# 188     189      0  昨晚 和 老婆 常 去 的 ， 在 点评 网 无意间 看到 御 兆 轩 ， 看着 评价 不错...
#
#
#      itemid  label                                             review
# 189     190      0  第二次 来 这里 。 这里 的 出品 很 不错 。 。 。 。 。 。 。 。 。 。 。 ...
#
#
#      itemid  label                                             review
# 190     191      0  因为 离 住家 很 近 ， 所以 接连 去 吃 了 两三次 ， 生意 超好 ， 每次 都 要...
#
#
#      itemid  label                                             review
# 191     192      0  去 光孝寺 的 ， 去 光孝寺 的 自助餐 。 。 。 。 。 。 。 。 。 。 。 。 ...
#
#
#      itemid  label                                             review
# 192     193      0  石牌 东 ， 学校 附近 ， 聚会 常 去 的 地方 。 环境 和 服务 都 是 一般般 ，...
#
#
#      itemid  label                                             review
# 193     194      0  环境 不错 ， 但是 我 是 花 了 一个 拔丝 地瓜 。 。 。 。 京 酱 肉丝 。 拔...
#
#
#      itemid  label                                             review
# 194     195      0  这家 意粉 屋 是 1979 年 由 一个 澳大利亚人 和 一个 美国 人 创办 的 ， 要...
#
#
#      itemid  label                                             review
# 195     196      0  老婆 想要 的 甜品 比较 多 的 一家 餐厅 ~ ~ 环境 还 可以 ， 环境 还 可以 ...
#
#
#      itemid  label                                             review
# 196     197      0  很 喜欢 这里 这里 的 镬 气 ， 很 有 镬 气 的 ， 菜量 也 很 不错 ， 服务员...
#
#
#      itemid  label                                             review
# 197     198      0  环境 不错 ， 但要 吃 电白 风味 了 。 这里 的 味道 不错 ， 值得 推荐 的 印象...
#
#
#      itemid  label                                             review
# 198     199      0  大 嘅 鲜虾 蟹子 云吞面 11 ( 5 粒 云吞 ) , 细 嘅 7 呅 ( 3 粒 云吞...
#
#
#      itemid  label                                             review
# 199     200      1  慕名而来 . 1 起 1 张 张 取消 . 1 路 , 1 路 , 1 路 , 1 路 , ...
#
#
#      itemid  label                                             review
# 200     201      1  去过 两次 ， 第一次 在 公司 吃 过 一次 ， 感觉 很 便宜 ， 很 便宜 ， 味道 ...
#
#
#      itemid  label                                     review
# 201     202      0  点 了 一个 特价 菜 ， 味道 很 好 ， 分量 够 滑 ， 价格 还 可以 。
#
#
#      itemid  label                                             review
# 202     203      0  在 广州 吃 过 的 套餐 不得不 说 奇差 无比 无比 无比 无比 无比 无比 无比 无比...
#
#
#      itemid  label                                             review
# 203     204      0  最 钟意 它家 的 麻薯 ， 好好 味 夹住 的 麻薯 ， 好好 味 ， 隔夜 夹住 的 馅...
#
#
#      itemid  label                                             review
# 204     205      0  第一次 去 的 时候 去 吃 ， 菜量 还 可以 。 点 了 一个 炸豆腐 ， 味道 还 可以 。
#
#
#      itemid  label                                             review
# 205     206      0  其实 是 周末 ， 所以 吃 完 多 东西 的 ， 东西 不 多 ， 一眼 的 东西 也 不...
#
#
#      itemid  label                                             review
# 206     207      0  元旦 全家人 中午 到 这家 酒家 吃饭 。 点 了 狗肉 煲 棚里 的 一张 大台 。 点...
#
#
#      itemid  label                                             review
# 207     208      0  我 在 这里 吃 完 之后 就 去 了 这家 店 的 店 鲶鱼 他 上错 了 鱿鱼 鲶鱼 小...
#
#
#      itemid  label                                             review
# 208     209      0  今天 去 的 时候 经常 来 吃 的 ， 觉得 味道 还 算 不错 ， 就是 银丝 面 ， ...
#
#
#      itemid  label                                             review
# 209     210      0  佰 搭果 ， 以前 钟意 去 的 榴莲 班戟 ， 对于 钟意 去 的 ， 因为 钟意 去 的...
#
#
#      itemid  label                                             review
# 210     211      0  一个 人 去 的 ， 这里 的 320 元 包做 汤 ， 可惜 下单 的 是 下单 的 32...
#
#
#      itemid  label                                             review
# 211     212      0  呢 间 的 时候 经常 去 吃 呢 ， 当时 就 五值甘贵 的 地方 ， 虽然 就 五值甘贵...
#
#
#      itemid  label                                             review
# 212     213      0  打印 了 优惠券 . 酸菜鱼 才 九元 九 . 就是 要 等位 . 点 了 一个 扣肉 夹膜...
#
#
#      itemid  label                                             review
# 213     214      0  那天 在 这里 吃 完 电影 ， 吃 完 12 月 ， 开 了 烧烤 ， 中午 去 吃 ， ...
#
#
#      itemid  label                                             review
# 214     215      1  豆豉 皇 肠粉 肠粉 确实 不错 ， 难怪 撒 的 感觉 ， 用布 铺底 ， 上面 撒 上 ...
#
#
#      itemid  label                                             review
# 215     216      0  潮式 ， 隐蔽 很 深 的 地方 ， 一时半刻 想不起来 的 ， 有 挑战性 。 卤水 拼盘...
#
#
#      itemid  label                                             review
# 216     217      0  这里 的 火锅 的 味道 都 很 不错 的 ， 但是 跟 其他 的 费用 低 一些 的 ， ...
#
#
#      itemid  label                                             review
# 217     218      0  Feb19 ... 早上 在 天河城 逛得 不亦乐乎 , 真 后悔 前一天 把 后悔 前一天...
#
#
#      itemid  label                                             review
# 218     219      0  很 高档 的 一家 餐厅 ， 人气 很 旺 ， 人气 很 旺 ， 人气 很 旺 ， 人气 还...
#
#
#      itemid  label                                             review
# 219     220      0  感觉 是 广州 的 ‘ 菜馆 。 味道 很 好 ， 而且 台桌 隔距 宽敞 ， 而且 台桌 ...
#
#
#      itemid  label                                             review
# 220     221      0  大昌 饮食 系 文昌 路 去 食 的 牛 牛 牛 朋友 推荐 去 的 沙河粉 ， 但 系 呢...
#
#
#      itemid  label                                             review
# 221     222      0  米粉 有点 糥 ， 米粉 比较 糥 ， 酸辣粉 的 汤 感觉 偏辣 ， 盖住 了 酸 的 菜...
#
#
#      itemid  label                                             review
# 222     223      0  麒胜是 一家人 气 挺 旺 的 粤菜馆 。 环境 也 不太好 ， 在 喧闹 的 城市 ， 就...
#
#
#      itemid  label                                             review
# 223     224      0  环境 不错 ， 烧鸭 很 咸 ， 出品 还 不错 ， 烧鸭 味道 一般 ， 烧鸭 很少 ， ...
#
#
#      itemid  label                                             review
# 224     225      0  看 了 广场 的 优惠券 ， 看 了 一圈 的 味道 ， 很 差 ， 中间 夹有 咸 牛油 ...
#
#
#      itemid  label                                             review
# 225     226      0  点 了 所谓 的 招牌 猪扒 哥 猪扒 饭 ， 整盘 都 是 红红的 西红柿 ， 跟着 猪扒...
#
#
#      itemid  label                                             review
# 226     227      1  冬季 吃火锅 的 好去处 ， 基本上 和 朋友 一起 每个 星期 至少 要 去 一次 ， 夏...
#
#
#      itemid  label                                             review
# 227     228      0  好久没 的 时候 经常 在 这里 吃 过 一次 ， 味道 很 不错 ， 就是 点 了 一份 ...
#
#
#      itemid  label                                             review
# 228     229      0  话 说 某日 ， 三藏 到 GZ 去 第二次 面签 ， 不管 在 天河 上 天河 个 天河 ...
#
#
#      itemid  label                                             review
# 229     230      0  老板娘 在 Noblecaf 的 小店 ， 突然 想 去 找 ， 突然 想 在 天河 吃饭 ...
#
#
#      itemid  label                                             review
# 230     231      0  也许 爱 上 一个 人 而 点 了 一个 ， 要不是 他 团 了 一个 ， 他 团 了 一个...
#
#
#      itemid  label                                             review
# 231     232      0  朋友 晚上 去 的 ， 慕名 推荐 。 点 了 菜 、 鹅 肝 、 甜品 、 甜品 、 甜品...
#
#
#      itemid  label                                             review
# 232     233      1  环境 很 好 ， 出品 很 旺 ， 出品 都 不错 ， 适合 这里 的 出品 都 不错 ， ...
#
#
#      itemid  label                                             review
# 233     234      1  过年 逗 的 利是 ， 通常 都 会 吃 过 一次 ， 从 初一 吃 的 十五 ~ ~ 这家...
#
#
#      itemid  label                                             review
# 234     235      0  这里 的 新疆 菜 就 不 爱 了 ， 这次 在 这里 吃饭 发现 。 煲仔菜 很 好 ， ...
#
#
#      itemid  label                                             review
# 235     236      0  朋友 开会 , 第一次 去 的 时候 就 去 吃 , 去 的 时候 都 是 吃 , 口味 的...
#
#
#      itemid  label                                             review
# 236     237      0  很 喜欢 这里 的 湘菜馆 越 多 ， 但 天娱 这 附近 ， 六点半 了 。 我 去 吃 ...
#
#
#      itemid  label                                             review
# 237     238      0  新 开张 吾 耐 ， 同 屋企 人 去 试下 啦 ， 由于 爸爸 未 起床 ， 由于 爸爸 ...
#
#
#      itemid  label                                             review
# 238     239      1  正好 在 这里 吃 过 三次 再 去 找 ， 就 找 了 这 地方 的 地方 。 点 了 一...
#
#
#      itemid  label                                             review
# 239     240      0  离 上班 离 三文鱼 里 的 地方 很 美味 ， 味道 很 好 ， 味道 很 好 ， 味道 ...
#
#
#      itemid  label                                             review
# 240     241      0  我 同 老公 去 过 ， 终于 系 想 去 食 。 但 系 我 话 想 吃 過 ， 但 系 ...
#
#
#      itemid  label                                             review
# 241     242      0  去 吃 过 一次 吃饭 ， 价格 偏贵 ， 菜谱 上 所有 的 菜 都 是 涨 了 价 的 ...
#
#
#      itemid  label                                             review
# 242     243      0  作为 广州 的 自助餐厅 之一 ， 价格 很 经济 ， 款式 也 比较 多 ， 比如 三文鱼...
#
#
#      itemid  label                                             review
# 243     244      0  许留山 重新 进入 人 多 ， 但 突然 想 去 踩 下场 啦 。 51 劳动节 下午 4 ...
#
#
#      itemid  label                                             review
# 244     245      1  一家 偏僻 的 农家 餐厅 。 味道 很 不错 ， 分量 有点 农家 农家 棚 ， 有 风扇...
#
#
#      itemid  label                                             review
# 245     246      1  要不是 肚子 很 涨 。 点 了 一个 口味 ， 一个 汤 ， 一个 豆腐 ， 一个 豆腐 ...
#
#
#      itemid  label                                             review
# 246     247      0  忘 了 潮州菜 就 在 这里 吃 了 。 那会儿 对 潮州菜 都 是 几年 的 。 那会儿 ...
#
#
#      itemid  label                                             review
# 247     248      1  三个 人 花 了 112 元 ， 但 不 浪费 。 点 了 鳝鱼 砂锅 粥 ， 一 笼 小笼...
#
#
#      itemid  label                                             review
# 248     249      0  这家 三口 ， 某 某 广州 的 评价 。 。 。 。 。 。 。 。 。 。 。 。 。 ...
#
#
#      itemid  label                                             review
# 249     250      1  作为 豆浆店 来说 不是 坚持 算是 不错 的 。 我 买 了 一个 茶 做 的 ， 做 的...
#
#
#      itemid  label                                             review
# 250     251      0  环境 很 好 ， 出品 很 好 ， 出品 很 好 ， 出品 很 好 ， 出品 很 好 ， 出...
#
#
#      itemid  label                                             review
# 251     252      1  以为 以为 是 越南 菜馆 ， 原来 这间 店 是 过去 的 ， 而是 类似 于 快餐 模式...
#
#
#      itemid  label                                             review
# 252     253      0  去 野生 动物园 玩 ， 在 点评 上 找 了 半天 周边 的 餐馆 。 环境 很 好 ， ...
#
#
#      itemid  label                                             review
# 253     254      0  喜欢 千变万化 的 米面 吃法 ， 觉得 提起 吃 感慨万千 的 时间 ， 便 会试 感慨万...
#
#
#      itemid  label                                             review
# 254     255      0  看 点评 去 的 ， 肠粉 皮薄 又 滑 ， 粥 底 也 不错 。 及第 粥 就 非常 一般...
#
#
#      itemid  label                                             review
# 255     256      0  和 大学 同学 过来 吃 过 的 龙俐 拉面 微辣 一个 龙俐 鱼 微辣 拉面 ， 吃 了 ...
#
#
#      itemid  label                                             review
# 256     257      0  环境 很 好 ， 出品 很 好 ， 环境 还 不错 。 。 。 。 。 。 。 。 。 。 ...
#
#
#      itemid  label                                             review
# 257     258      0  很 喜欢 的 一家 餐厅 , 可能 是 晚上 去 的 , 这里 的 是 性价比 不错 , 环...
#
#
#      itemid  label                                             review
# 258     259      0  同事 上次 去 过 , 话 话 话 话 好 细 , 但 话 有 6.8 折 , 还点 左 送...
#
#
#      itemid  label                                             review
# 259     260      0  喜欢 吃 一切 带馅 的 面食 ， 味道 不错 ， 软硬 适中 ， 软硬 适中 ， 软硬 适...
#
#
#      itemid  label                                             review
# 260     261      1  环境 很 一般 ， 有点像 大排档 ， 6 个人 ， 吃 了 一个 鱼 、 鱼 、 鱼 、 ...
#
#
#      itemid  label                                        review
# 261     262      1  次次 都 是 冲 去 那么 好吃 。 点 了 一个 雪山 杨枝 甘露 ， 味道 不错 。
#
#
#      itemid  label                                             review
# 262     263      1  招牌 粉 很 好吃 ， 双皮奶 也 很 多 ， 其他 的 马马虎虎 菜 的 味道 也 很 一...
#
#
#      itemid  label                                             review
# 263     264      0  好 耐 都 系 成 多 , 琴 日 话 去 左 公司 ， 突然 想 去 试下 , 但 系 次...
#
#
#      itemid  label                                             review
# 264     265      0  唔 系 想 去 噶 ， 差差差差差差差差差差差差差差差差差差差差差差差差差差差差差差差差差差...
#
#
#      itemid  label                                             review
# 265     266      0  那天 来 最贵 的 专门店 ， 价钱 当然 是 传统 的 缘故 ， 不过 价钱 都 是 传统...
#
#
#      itemid  label                                             review
# 266     267      1  这里 的 粤菜 风味 ， 每次 都 是 吃 顺德 菜 的 ， 味道 还 不错 ， 每次 必点...
#
#
#      itemid  label                                             review
# 267     268      0  第一次 去 既 时候 ， 系 系 巨 既 奶茶 紧 紧 ， 真系 系 DAKASI 好 大 ...
#
#
#      itemid  label                                             review
# 268     269      0  之前 在 点评 见到 感 多 ， 于是 去 试下 啦 。 点 左 38 分钟 ， 等 左 好...
#
#
#      itemid  label                                             review
# 269     270      0  因为 离家近 ， 所以 办 了 卡 ， 味道 很 不错 。 。 。 。 。 。 。 。 。 ...
#
#
#      itemid  label                                             review
# 270     271      0  有天 中午 去 吃 的 ， 人 不算 多 ， 所以 周围 旁边 的 人 。 烤肉 比较 多 ...
#
#
#      itemid  label                                             review
# 271     272      1  今日 去上 影联 和 睇 戏 ， 顺便 顺便 喺 燕 汇 吃饭 了 。 搵 咗 呢 间 ， ...
#
#
#      itemid  label                                             review
# 272     273      1  09 07 07 - - 15 早就 摇车 去 同德 围 的 , 终于 话 话 话 摇车 去...
#
#
#      itemid  label                                             review
# 273     274      1  常常 听说 番禺 是 一家 餐厅 拉 甚 多 ， 去 常常 是 公道 ， 奈何 太 远 ， ...
#
#
#      itemid  label                                             review
# 274     275      0  今 次 已经 系 第二次 黎 呢间 野 食 .... 今次 都 唔 错 .... D 台 都...
#
#
#      itemid  label                                             review
# 275     276      0  本来 要 了 个 地税局 办事 ， 发现 诗书 路 说 这家 店 ， 本人 嗜 吃 越秀区 ...
#
#
#      itemid  label                                             review
# 276     277      0  去过 两三次 ， 拉 肠 都 不错 ， 价钱 稍 贵 ， 价钱 稍 贵 ， 价钱 稍 贵 ，...
#
#
#      itemid  label                                             review
# 277     278      0  接到 通知 去 试吃 , 接到 看 点评 网友 接到 人 去 的 ， 坐地铁 宝业 地图 站...
#
#
#      itemid  label                                             review
# 278     279      0  看 竹升面 很 难 找 的 ， 看 了 制作 的 图片 后 图片 找 了 ， 墙上 也 有 ...
#
#
#      itemid  label                                             review
# 279     280      0  就是 在 广州 的 时候 去 吃 了 一个 套餐 ， 味道 还 不错 , 就是 价格 有点 ...
#
#
#      itemid  label                                             review
# 280     281      0  布拉格 ， 布拉 肠 ， 傻傻 分不清楚 。 在 魔 就 去 的 时候 就 去 的 时候 就...
#
#
#      itemid  label                                             review
# 281     282      0  我 去过 过 一次 ， 真的 是 几 好 ， 所以 系 去过 ， 朋友 觉得 几 好 ， 所...
#
#
#      itemid  label                                             review
# 282     283      0  以前 去 的 时候 经常 去 吃 ， 去 的 时候 才 多 到 一次 。 点 了 一个 特价...
#
#
#      itemid  label                                             review
# 283     284      0  环境 不错 ， 古香古色 、 佛音 绕 耳 、 点心 、 汤 、 出品 都 不错 ， 古香古...
#
#
#      itemid  label                                             review
# 284     285      0  杂志 的 是 正宗 的 一家 粤菜馆 ， 味道 很 不错 ， 菜势 不错 ， 菜势 不错 ，...
#
#
#      itemid  label                                             review
# 285     286      0  每次 经过 都 要 等位 ， 不过 宜家 都 要 等位 。 我 要 了 d 菜 底 ， 不过...
#
#
#      itemid  label                                             review
# 286     287      0  。 。 沈生 在 华乐路 的 老店 。 。 原本 就 不是 在 华乐路 的 老店 。 。 。...
#
#
#      itemid  label                                             review
# 287     288      0  刚好 去 果 阵 就 系 距 野 ， 所以 都 系 呢 度 去 的 ， 所以 甘样 都 系 ...
#
#
#      itemid  label                                             review
# 288     289      0  从 一楼 上 好似 好 细 ， 算系 几大间 咖 分店 ， 就 去 试下 啦 。 算系 几大...
#
#
#      itemid  label                                             review
# 289     290      0  两个 人 去 食 ， 两条 友 ， 一个 拼盘 ， 一个 咸猪 手 ， 一个 沙律 饱到 上...
#
#
#      itemid  label                                             review
# 290     291      1  地方 不太好 ， 开车 兜 了 个 大圈 才 找到 。 假期 去 的 时候 去 吃 的 ， ...
#
#
#      itemid  label                                             review
# 291     292      0  老实 讲 ， 人地 话 呢 间野 去 到 ， 但 系 次次 都 系 呢 间野 去 ， 但 系...
#
#
#      itemid  label                                             review
# 292     293      0  每次 去 吃 过 一次 ， 每次 都 是 第一次 去 。 去 了 大家乐 ， 每次 去 都 ...
#
#
#      itemid  label                                             review
# 293     294      0  南乐 酒家 ( 基立 南街 老店 ) ， 他家 的 招牌 蟾蜍 店 都 是 姐姐 提醒 了 ...
#
#
#      itemid  label                                             review
# 294     295      1  一個 字 ： 差 ！ 差 ！ 差 ！ 差 ！ 差 ！ 差 ！ 差 ！ 差 ！ 差 ！ 差 ！...
#
#
#      itemid  label                                             review
# 295     296      0  在 恒宝 广场 对面 的 小店 ， 店铺 很窄 ， 就 在 街口 处 ， 做事 的 还是 些...
#
#
#      itemid  label                                             review
# 296     297      0  记得 系 东方 宝泰 友人 馆岩 开 个 时 火窝 火窝 任食 ( 39 肥牛 火窝 升到 ...
#
#
#      itemid  label                                             review
# 297     298      0  水稻田 酒家 是 一家 粤菜馆 , 在 华景 小区 的 会所 二楼 . 这家 餐馆 的 服务...
#
#
#      itemid  label                                             review
# 298     299      0  以前 系 公寓 住 的 时候 去 ， 见到 挂有 写著 ， 见到 挂有 写著 ， 见到 挂有...
#
#
#      itemid  label                                             review
# 299     300      0  这家 的 清炖鸡 是 目前为止 吃 的 感觉 比较 好吃 的 ， 强烈推荐 ！ 其它 的 菜...
#
#
#      itemid  label                                             review
# 300     301      0  去 在 这里 的 时候 去 吃 的 好去处 。 半夜 的 中山 立交 旁 旁 的 好去处 。...
#
#
#      itemid  label                                             review
# 301     302      0  很 喜欢 广州 茶餐厅 ， 在 附近 吃 了 一回 ， 半个 日 之内 去过 了 ， 去 的...
#
#
#      itemid  label                                             review
# 302     303      0  很久没 去 光顾 的 时候 恵 福 路 正在 修路 ， 现在 恵 福 路 正在 修路 ， 搞...
#
#
#      itemid  label                                             review
# 303     304      1  虽然 是 附近 是 团购 的 一家 食肆 的 店 ， 这次 吃 了 一回 。 虽然 是因为 ...
#
#
#      itemid  label                                             review
# 304     305      0  昨天晚上 差不多 11 点 左右 去 的 。 前段 日子 的 是 前段 好 的 。 前段 日...
#
#
#      itemid  label                                             review
# 305     306      1  每次 都 是 冲 的 大餐 ， 一下子 变成 了 13 大餐 的 大餐 ~ ~ 几乎 吃 了...
#
#
#      itemid  label                                             review
# 306     307      1  个个 都 係 蟾蜍 ， 试 过 两斤 去 到 ， 就 唔 住 试 过 。 试 过 两斤 的 ...
#
#
#      itemid  label                                             review
# 307     308      0  房间 不太好 ， 散位 不 多 ， 散位 说 的 ， 好像 260 元 的 。 味道 很 一...
#
#
#      itemid  label                                             review
# 308     309      0  ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ∷ ...
#
#
#      itemid  label                                             review
# 309     310      0  第一次 去 试吃 ， 半价 旋转 15 元 左右 ， 旋转 旋转 餐桌 ， 牛拍叶 ， 旋转...
#
#
#      itemid  label                                             review
# 310     311      0  冰啡 也 挺 好 的 ， 服务 也 不错 。 最 喜欢 这里 的 三文鱼 、 粥 、 金枪鱼...
#
#
#      itemid  label                                             review
# 311     312      1  新开 的 时候 一直 来 这里 吃 了 ， 真的 是 很 多 的 。 。 味道 也 不错 ，...
#
#
#      itemid  label                                             review
# 312     313      0  电话 沟通 过 了 ， 大年初一 2 月 14 日 自助餐 （ 晚 ） 688 + 15 %...
#
#
#      itemid  label                                             review
# 313     314      0  生日 聚会 在 这里 网上 找到 这家 餐厅 的 ， 在 体育 这样 的 闹市 地带 的 一...
#
#
#      itemid  label                                             review
# 314     315      0  琴 晚 见到 六折 就 入去 试下 。 隔离 间 韩 情 D 烧烤 ， 筑 地虾 一食 就 ...
#
#
#      itemid  label                                             review
# 315     316      0  這里 早上 勁 多 老伯伯 系度 飲 早茶 .. 一 早就 勁 多 老伯伯 系度 飲 早茶 ...
#
#
#      itemid  label                                             review
# 316     317      0  就 系 云台 花园 旁边 ， 行 左 白云山 就 刚好 去 吃 番 餐 。 沙河粉 味道 唔...
#
#
#      itemid  label                                             review
# 317     318      0  以前 在 我 工作 的 时候 在 附近 工作 的 人 在 我 工作 的 时候 去 吃 过 ，...
#
#
#      itemid  label                                             review
# 318     319      0  奔波 一天 再 赶去 吃 百岁 鸡 ， 真系 几 难 搵 ， 带路 果 个 本身 就 系 方...
#
#
#      itemid  label                                             review
# 319     320      0  环境 很 不错 ， 环境 很 好 ， 但 味道 很 好 ， 但 味道 还 不错 ， 就是 可...
#
#
#      itemid  label                                             review
# 320     321      1  中午 的 星巴克 , 通常 就 系 朋友 去 , 通常 去 试下 , 通常 就 会 去 鬼佬...
#
#
#      itemid  label                                             review
# 321     322      0  在 晓港 地铁站 附近 开 了 一年 去 的 ， 在 广州 ” 的 地方 非常 近 ， 有天...
#
#
#      itemid  label                                             review
# 322     323      0  冲着 东来顺 的 名气 来 的 。 总体 来说 挺 满意 的 ， 总体 回味 的 是 回味 ...
#
#
#      itemid  label                                             review
# 323     324      0  走进 走进 去 的 ， 这里 的 时候 爆满 了 ， 看着 墙上 挂 着 的 很多 明星 照...
#
#
#      itemid  label                                             review
# 324     325      1  我 在 附近 住 ， 所以 去 开时 我 就 去 捧场 ， 刚 去 的 时候 就 有 一次 ...
#
#
#      itemid  label                                             review
# 325     326      0  地处 商场 旺地 ， 地方 比较 挤逼 ， 地方 比较 挤逼 ， 气氛 比较 吵杂 ， 所以...
#
#
#      itemid  label                                             review
# 326     328      0  半份 脆皮 猪 肘 ， 这里 的 大约 2 斤 ， 158 元 ， 猪肉 酸菜 的 味道 ，...
#
#
#      itemid  label                                             review
# 327     329      1  鱼 嘴 蒸滑 鸡 真是 绝品 ， 鱼 嘴 极滑 ， 鸡肉 极鲜 。 生抽 骨 的 味道 都 ...
#
#
#      itemid  label                                             review
# 328     330      1  稻香 的 老板 经营 真的 有 一套 。 广州 每家 稻香 都 是 门庭若市 。 那天 在 ...
#
#
#      itemid  label                                             review
# 329     331      0  从 天河城 出来 的 地方 越 多 了 ， 突然 想 吃 鳗鱼 ， 突然 想 想到 鳗鱼 、...
#
#
#      itemid  label                                             review
# 330     332      1  在 商场 里面 ， d 下午茶 都 算 好 平 ， x 虫 那类 平民 西餐厅 的 feel...
#
#
#      itemid  label                                             review
# 331     333      1  在 广州 生活 了 很多年 ， 长期 在 广州 生活 了 很多年 ， 长期 在 天河 混混 ...
#
#
#      itemid  label                                             review
# 332     334      0  人气 很旺 的 酒楼 ， 菜色 、 菜色 都 不错 。 价钱 比较 大 ， 出品 也 不错 ...
#
#
#      itemid  label                                             review
# 333     335      0  参加 大洋 的 美食 兵团 去 尝鲜 ， 这里 的 味道 也 不错 ， 味道 也 不错 ， ...
#
#
#      itemid  label                                             review
# 334     336      0  听到 第一 是 酸菜鱼 ： 酸菜鱼 的 味道 都 可以 ， 可以 喝 白切鸡 ， 味道 还 ...
#
#
#      itemid  label                                             review
# 335     337      1  环境 还 不错 ， 环境 还 可以 ， 环境 还 可以 ， 环境 也 不错 ， 价格 也 比...
#
#
#      itemid  label                                             review
# 336     338      1  刚 开张 时 ， 去 的 时候 去 8.8 折 ， 不 知道 是不是 点 了 红豆 片 （ ...
#
#
#      itemid  label                                             review
# 337     339      0  如今 如今 的 餐厅 ， 抱歉 的 环境 很 差 ， 改完 榜单 ， 就此 展开 ， 优先 ...
#
#
#      itemid  label                                             review
# 338     340      0  点评 网 慕名而来 ， 可惜 杨枝 金露 的 榴莲 ， yeah ， 双 肥奶 要 试 了 ...
#
#
#      itemid  label                                             review
# ...
# 633     639      0  看 万达 广场 的 万达 广场 里 的 地方 之一 ， 店里 的 挨 桌子 摆 得 满满的 ...
#
#
#      itemid  label                                             review
# 634     640      0  这里 的 味道 很 不错 ， 很 甜 ， 有点 甜 ， 有点 甜 ， 不 甜 了 些 ， 有...
#
#
#      itemid  label                                             review
# 635     641      1  今天 父亲节 , 小姑 和 家婆 们 与 家婆 们 与 家婆 们 发生 口角 , 但 昨天 ...
#
#
#      itemid  label                                             review
# 636     642      0  正门 进来 直 上 电梯 ， 即见 这 一 颇具 粤 味 后 座椅 ， 既有 快餐 氛围 ，...
#
#
#      itemid  label                                             review
# 637     643      1  某 亲戚 曾经 去 了 ， 突然 想 去 找 ， 突然 想 去 找 ， 突然 想 去 找 ，...
#
#
#      itemid  label                                             review
# 638     644      0  我 非常 喜欢 这里 的 酒吧 ， DJ 非常 大声 ， 就是 一家 二战 士兵 服装 的 ...
#
#
#      itemid  label                                             review
# 639     645      1  今天下午 在 晓港 地铁站 附近 ， 在 点评 网 看见 在 地铁站 的 餐厅 ， 看见 在...
#
#
#      itemid  label                                             review
# 640     646      0  据说 表叔 是 表哥 的 升级版 ， 表叔 ！ 本来 是 在 广州 楼下 的 升级版 ， 表...
#
#
#      itemid  label                                             review
# 641     647      1  星期六 来 试吃 半价 优惠活动 ， 始终 星期六 试 过 优惠活动 ， 始终 都 觉得 一...
#
#
#      itemid  label                                             review
# 642     648      1  新 开张 ， 由于 美 人 多 ， 所以 一直 想 去 吃 ， 就 去 了 。 地方 多 了...
#
#
#      itemid  label                                             review
# 643     649      1  在 微博 上 看到 这家 新店 ， 在 天河 邮局 附近 ， 走到 着 河南 二路 那边 去...
#
#
#      itemid  label                                             review
# 644     651      0  最 爱 吃 个 中麻 中 辣 ， 搞 到 JJ 连呼辣 S 了 ~ ~ 以 4 家 2 家 ...
#
#
#      itemid  label                                             review
# 645     652      0  人气 很 旺 ， 这晚 很 旺 ， 这晚 也 很 旺 ， 这晚 都 很 旺 ， 环境 很 不...
#
#
#      itemid  label                                             review
# 646     653      1  这家 店 是 容易 容易 找到 ， 出 了 地铁 员村 站 就 看到 了 这家 。 环境 很...
#
#
#      itemid  label                                             review
# 647     654      0  我 同 老婆 两个 人 去 食 嘢 ， 我 都 系 呢 度 试 过 ， 我 都 系 呢 度 ...
#
#
#      itemid  label                                             review
# 648     655      0  团 了 个 19.9 的 芝士 蛋糕 ， 今天 团 了 个 19.9 的 芝士 蛋糕 ， 点...
#
#
#      itemid  label                                             review
# 649     656      0  临江 大道 ， 新 了 科韵路 再 往 东 开张 。 。 。 。 。 。 。 。 。 。 。...
#
#
#      itemid  label                                             review
# 650     657      1  呢 间野 同 BF 好无语 ， 纯粹 系 广州日报 既 美食 导报 果度 卖 广告 ， 就 ...
#
#
#      itemid  label                                             review
# 651     658      1  如果 不是 團購 了 ￥ 9.9 的 6 寸重 芝士 櫻 花蝦 pizza 都 沒 有什 麽...
#
#
#      itemid  label                                             review
# 652     659      0  环境 很 不错 ， 很难 精致 。 人参 鹅 很滑 ， 适合 一个 人 的 味道 ， 味道 ...
#
#
#      itemid  label                                             review
# 653     660      0  几个 月前 试过 一次 ， 特制 pizza 相当 脆 ， 最 好吃 的 。 。 千万别 放...
#
#
#      itemid  label                                             review
# 654     661      0  要 了 个 鸡翅 沙律 陪 鸡翅 ， 味道 不怎么样 ， 咸七 柠 ， 失去 柠 配 上 咸...
#
#
#      itemid  label                                             review
# 655     662      0  环境 很 好 ， 出品 比 出品 都 不错 的 。 服务 还 算 可以 。 出品 比较 好 ...
#
#
#      itemid  label                                             review
# 656     663      0  两年 两年 太 多 ， 风景 ， 风景 ， 风景 ， 风景 ， 风景 ， 风景 不错 ， 风...
#
#
#      itemid  label                                             review
# 657     664      0  点评 网 团购 的 ， 在 点评 网 的 团购 ， 看 了 一颗 星 。 本来 一直 一直 ...
#
#
#      itemid  label                                             review
# 658     665      0  音响 一般般 ， 自助餐 更是 一般般 ， 环境 也 很 不错 。 。 。 。 。 。 。 ...
#
#
#      itemid  label                                             review
# 659     666      0  日日 坐地铁 行 过 嘅 布丁 布丁 ， 真系 好 好 食 ， 好 好 好 ， 好 好 食 ...
#
#
#      itemid  label                                             review
# 660     667      0  我 在 点评 住 附近 ， 想不到 越做越 旺 ， 甚至 有 同事 向 我 去 住 在 附近...
#
#
#      itemid  label                                             review
# 661     668      0  最近 各路 亲戚 积极 拓展 茶餐厅 事业 ， 在 广州 遍地开花 · · · 表叔 表哥 ...
#
#
#      itemid  label                                             review
# 662     669      1  铺面 不怎么 起眼 ， 但 农夫 包 的 面包 部分 和 面包 里面 的 。 味道 配合 的...
#
#
#      itemid  label                                             review
# 663     670      0  因为 甘岩 两个 人 吃 ， 但 系 系 一日 ， 所以 琴 晚去 ， 所以 琴 晚去 ， ...
#
#
#      itemid  label                                             review
# 664     671      0  行 过 龙泉 二楼 ， 发现 唔 多 到 一间 ， 由 阿妈 记同 K 记 既 物价 午餐 ...
#
#
#      itemid  label                                             review
# 665     672      0  这家 店 是 新开 的 ， 新派 的 装修 ， 灯光 明亮 ， 装修 还 算 不错 。 。 ...
#
#
#      itemid  label                                             review
# 666     673      0  今天 试吃 了 一个 茶点心 • • • • • • 详细 的 图图 迟些 会 发在 食 •...
#
#
#      itemid  label                                    review
# 667     674      0  环境 不错 ， 环境 很 不错 。 环境 更是 很 舒服 ， 环境 也 不错 。
#
#
#      itemid  label                                             review
# 668     675      0  第一次 吃 德国 菜 ， 感觉 还 可以 ， 环境 还 可以 ， 环境 还 可以 ， 环境 ...
#
#
#      itemid  label                                             review
# 669     676      0  住 在 远洋 宾馆 早餐 就 在 27 楼 就 在 27 楼 ， 在 27 楼 ， 早餐 都...
#
#
#      itemid  label                                             review
# 670     677      0  听说 这里 蛇 做 的 不错 ， 只好 两 人 两 两 小朋友 ， 点 了 一条 榕蛇 2 ...
#
#
#      itemid  label                                             review
# 671     678      0  玩 了 很多 下午 3 点 的 自助餐 ， 小房 35 元 每 小时 ， 8 点 每位 买单...
#
#
#      itemid  label                                             review
# 672     679      0  佢 的 本身 都 会 住 南村 路 ， 男友 自己 住 南村 路 ， 男友 都 会 住 南村...
#
#
#      itemid  label                                             review
# 673     680      1  这个 商场 外表 觉得 华丽 丽 的 其实 " 内涵 " 还 真的 很 一般 其实 嘴巴 很...
#
#
#      itemid  label                                             review
# 674     681      0  牛腩 粉 ， 牛 三星 ， 味道 不错 ， 牛腩 半透明 牛腩 ， 牛腩 很脆 Q ， 牛腩...
#
#
#      itemid  label                                             review
# 675     682      0  我 去过 篇 点评 网 ， 让 我 打算 去 去 的 ， 所有 的 所有 上 所有 或者 银...
#
#
#      itemid  label                                             review
# 676     683      0  华农 大 西点 屋 馒头 ， 非常 正点 ， 每天 必 买 ， 一直 表扬 华农 的 酸奶 ...
#
#
#      itemid  label                                             review
# 677     684      0  两个 人 自带 了 10 元 带子 ， 斤半 圣子 上楼 ， 侍应 说 要 再 点 个 小炒...
#
#
#      itemid  label                                             review
# 678     685      0  众多 的 毛家 店 ， 我 吃 过 不下 三次 。 味道 不错 ， 味道 也 不错 。 以前...
#
#
#      itemid  label                                             review
# 679     686      0  经过 珠江 新城 ， 休息 的 时候 去 下午茶 ， 休息 一下 。 环境 明亮 ， 人员 ...
#
#
#      itemid  label                                             review
# 680     687      1  在 南方 医院 附近 大概 是 数一数二 的 酒楼 了 ， 味道 不错 ， 点 了 几波 人...
#
#
#      itemid  label                                             review
# 681     688      0  真的 很 不错 哎 ， 在 点评 上 看到 说 上菜 慢 ， 披萨 也 不错 ， 分割 不错...
#
#
#      itemid  label                                             review
# 682     689      0  中午 时段 去 吃 ， 进来 试试 。 点 了 一个 汤 意粉 ， 意粉 ， 不失 ； 蘑菇...
#
#
#      itemid  label                                             review
# 683     690      0  同 青柳 大街 开 咗 好多年 嘅 面店 ， 于是 入 去 入 去 试下 。 呢 间 之后 ...
#
#
#      itemid  label                                             review
# 684     691      0  这家 店 无疑 是 新开 的 ， 皆 因 下班 下班 ， 环境 还 算 宽松 ， 谈话 得 ...
#
#
#      itemid  label                                             review
# 685     692      0  周六 来 喝茶 ， 环境 还 可以 ， 人气 很 旺 ， 但是 人气 还 可以 ， 人气 还...
#
#
#      itemid  label                                             review
# 686     693      0  在 点评 网上 看到 远洋 宾馆 海龙 厅 的 团购 ， 三 人 ， 要么 团 了 下来 ，...
#
#
#      itemid  label                                             review
# 687     694      0  之前 自己 试过 整姜 撞 奶 ， 失败 了 ， 去 出来 就 觉得 好 了 。 风行 牛奶...
#
#
#      itemid  label                                             review
# 688     695      0  这里 的 寿司店 很 好吃 ， 环境 还 不错 ， 环境 很 不错 ， 喜欢 吃 批 萨 找...
#
#
#      itemid  label                                             review
# 689     696      0  响 黄埔 万岁 去 噶 ， 撞 甘有 5 折 ！ 唔 知 系米 心理作用 啦 ， 唔 知 系...
#
#
#      itemid  label                                             review
# 690     697      0  一个 进店 的 韩式 菜馆 ， 味道 很 不错 。 。 。 。 。 。 。 。 。 。 。 ...
#
#
#      itemid  label                                             review
# 691     698      1  是 吃 清远 鸡 为主 的 小店 ， 门面 比较 小 ， 环境 还 不错 。 据说 是 “ ...
#
#
#      itemid  label                                             review
# 692     699      1  系 老字号 的 老字号 越黎 越少 ， 但 都 几 中意 呢度 饮茶 ， 贪距 有 人 直落...
#
#
#      itemid  label                                             review
# 693     700      0  4 个人 去 的 ， 菜量 还行 。 拉皮 味道 还行 。 拉皮 味道 还行 。 拉皮 味道...
#
#
#      itemid  label                                             review
# 694     701      0  从 东北 门 进去 , 小店 不错 , 小杯 小资 情调 , 非常适合 逛街 走累 时 时 ...
#
#
#      itemid  label                                             review
# 695     702      1  响 北京路 甘样 的 价钱 都 算平 ， 距地 的 肠粉 都 几 好 ， 唯一 好 抵 的 ...
#
#
#      itemid  label                                             review
# 696     703      1  因为 在 公司 附近 ， 所以 却是 却是 却是 却是 却是 却是 却是 却是 却是 却是 ...
#
#
#      itemid  label                                             review
# 697     704      0  环境 不错 ， 服务 也 不错 ， 服务 也 不错 。 服务 舒适 ， 服务 还 可以 。 ...
#
#
#      itemid  label                                             review
# 698     705      0  家里 不想 煮饭 就 来 了 一次 。 。 。 。 。 。 。 。 。 。 。 。 。 。 ...
#
#
#      itemid  label                                             review
# 699     706      0  下班 和 表姨 请客 的 时候 都 是 在 广州 在 广州 的 时候 去 吃 的 时候 都 ...
#
#
#      itemid  label                                             review
# 700     707      0  3.19 日 周六 人 真多 出门 靠右 看到 开 了 家 面包 新语 嗯 很久没 在 广州...
#
#
#      itemid  label                                             review
# 701     708      0  店铺 细细 间 ， 碟头 细细 碟 ~ ~ 家庭式 作坊 的 越南 餐厅 ~ ~ 家庭式 作...
#
#
#      itemid  label                                             review
# 702     709      0  听 同事 讲 呢 边 开 左间 大家乐 ， 因为 烈日当空 ， 确实 大汗淋漓 。 呢 度系...
#
#
#      itemid  label                                             review
# 703     710      1  环境 ： 餐厅 大至 分为 两层 ， 紫色 以 紫色 为主 调 ， 每处 卡座 都 有 粉 ...
#
#
#      itemid  label                                             review
# 704     711      0  还 挺 有 特色 ， 味道 也 还行 ， 价格 也 还行 。 另 点 了 一个 墨西哥 帽 ...
#
#
#      itemid  label                                             review
# 705     712      0  我 是 太太 是 江苏 人 ， 平时 都 是 江苏 人 ， 所以 在 中华 广场 购物 之后...
#
#
#      itemid  label                                             review
# 706     713      0  本周 和 客户 吃 过 的 分店 ， 和 西北 呆 的 。 它家 的 味道 很 不错 。 烤...
#
#
#      itemid  label                                             review
# 707     714      0  金碧 近 世界 喝茶 的 地方 , 很多 喝茶 , 环境 还 不错 , 中午 喝茶 , 中午...
#
#
#      itemid  label                                             review
# 708     715      0  环境 非常 恶劣 ， 服务 也 不太好 。 点 了 一个 招牌 肉饼 饭 、 一个 招牌 蛋...
#
#
#      itemid  label                                             review
# 709     716      0  最 喜欢 它家 的 特价 菜 ... 它家 的 味道 很 好 弹牙 ， 味道 很 好 弹牙 ...
#
#
#      itemid  label                                             review
# 710     717      0  东西 中规中矩 味道 中规中矩 ， 不过 环境 一般 ， 而且 环境 不错 ， 性价比 高 ...
#
#
#      itemid  label                                             review
# 711     718      0  暂时 觉得 性价比 最高 的 粤菜 了 ， 表哥 ， 表哥 ， 表哥 ， 表哥 ， 表哥 ，...
#
#
#      itemid  label                                             review
# 712     719      0  两 人 吃 正正好好 正正好好 。 菜量 还 算 不错 。 。 。 。 。 。 。 。 。 ...
#
#
#      itemid  label                                             review
# 713     720      0  广州 洛溪 大桥 湘村 爱 的 店 ， 湘村 人家 。 提 着 购物 的 大 包小包 就 去...
#
#
#      itemid  label                                             review
# 714     721      0  最近 标错 了 一次 ， 去 的 时候 去 过去 就 过去 了 。 环境 很 好 ， 味道 ...
#
#
#      itemid  label                                             review
# 715     722      0  住 在 白云 国际会议中心 ， 紫缘轩 就 在 白云 国际 对面 的 云溪 生态 公园 内 ...
#
#
#      itemid  label                                             review
# 716     723      0  十几年 前 ， 没有 真功夫 、 粥 粉面 档 ， 大西 豪 就是 首选 。 它 的 蜜香汁...
#
#
#      itemid  label                                             review
# 717     724      0  可以 用 平 、 靓 、 正 形容 ， 每 旧 1 蚊 起 ， 可能 即整 既 关系 ， 烤...
#
#
#      itemid  label                                             review
# 718     725      0  本來 想試 下 個 全 肥牛 米 線 誰 知 個 服務員 一 挪 D 肥牛 出 黎 D 肥牛...
#
#
#      itemid  label                                             review
# 719     726      1  强烈 谴责 点评 网 的 网络 ， 在 点评 网 的 网络 都 不见 了 ！ ！ 家住 番禺...
#
#
#      itemid  label                                             review
# 720     727      0  今日 系个 好 重要 的 日子 ， 试 过 下 。 装修 ， 真系 好 少 。 装修 ， 真...
#
#
#      itemid  label                                             review
# 721     728      0  离开 左 星期 ， 翻 到来 饮茶 瘾 即使 起 ， 边度 几 舒服 ， 即刻 谂 到 建 ...
#
#
#      itemid  label                                             review
# 722     729      0  这家 店 是 新开 的 。 。 如果 如果 有点 辣 。 。 。 如果 可以 吃 一些 的 ...
#
#
#      itemid  label                                             review
# 723     730      1  首先 ， 要 骂 坐地铁 ， 无奈 步行 再 再 再 再 再 再 再 再 再 再 再 再 再...
#
#
#      itemid  label                                             review
# 724     731      1  终于 喜欢 了 牛藏 ， 也 不是 传说 中 的 好吃 ， 卡路 不错 。 。 。 。 。 ...
#
#
#      itemid  label                                             review
# 725     732      0  由 广州 酒家 经营 管理 的 天 极品 改 了 一个 极容易 引 人 遐想 的 是 极容易...
#
#
#      itemid  label                                             review
# 726     733      0  晕 。 居然 最 喜欢 这里 的 五花肉 ， 坐 了 兄弟姐妹 。 。 。 。 。 。 。 ...
#
#
#      itemid  label                                             review
# 727     734      0  【 新闻 概述 】 参考 稍息 2010 年 5 月 26 日 — — — — — — — ...
#
#
#      itemid  label                                             review
# 728     735      0  因为 离 家里 近 ， 所以 冬天 的 时候 经常 来 吃 ， 可以 吃 过 几次 ， 味道...
#
#
#      itemid  label                                             review
# 729     736      1  让 人 回到 了 读书 ， 排队 打饭 ， 排队 ， 排队 ， 排队 的 。 土豆丝 、 青...
#
#
#      itemid  label                                             review
# 730     737      1  经过 到 这家 店 的 ， 主要 是 第一次 去 。 这间 店 有款 菜椒 饺子 ， 不辣 ...
#
#
#      itemid  label                                             review
# 731     738      0  曾经 听说 过 这 名字 ， 猜想 应该 是 地道 的 广东 馆子 ， 做东 的 好友 ， ...
#
#
#      itemid  label                                             review
# 732     739      1  布丁 很 可爱 的 焦糖 造型 蛋糕 , 比如说 " AngryBird " 的 焦糖 造型...
#
#
#      itemid  label                                             review
# 733     740      1  每次 都 是 这里 的 常客 , 每周 这里 的 常客 . 每周 玩 的 时候 都 是 这里...
#
#
#      itemid  label                                             review
# 734     741      0  记得 在 广州 的 时候 都 是 以前 去 的 时候 吃 的 时候 去 的 ， 但 现在 的...
#
#
#      itemid  label                                             review
# 735     742      1  我 来 吃 吃 的 ， 阿妈 推荐 ， 新开 的 茶市 ， 都 是 有 一种 好吃 的 。 ...
#
#
#      itemid  label                                             review
# 736     743      1  跟 朋友 出去玩 就 住 对面 就 去 喝 早茶 ， 去 的 时候 就 忍不住 去 试试 ，...
#
#
#      itemid  label                                             review
# 737     744      1  这 是 我 吃 过 最贵 的 盒饭 哦 ， 160 块 ， 但是 加 着 加 着 加 了 的...
#
#
#      itemid  label                                             review
# 738     745      0  好 地方 ， 喜静 的 人会 比较 多 ， 所以 人气 还 可以 ， 环境 还 可以 ， 环...
#
#
#      itemid  label                                             review
# 739     746      0  在 Noblecaf 的 e 露天 阳台 望 到 小蛮 腰 美景 ， 都 是 一种 一种 ，...
#
#
#      itemid  label                                             review
# 740     747      0  去 了 都 会 去 吃 ， 点 了 一个 炸豆腐 套餐 ， 味道 同仙仔 有 得 辉 ； 还...
#
#
#      itemid  label                                             review
# 741     748      1  广州市区 的 萨莉亚 都 人山人海 ， 番禺 繁华 店 由于 是 新开 的 暂时 人流 还 ...
#
#
#      itemid  label                                             review
# 742     749      0  人气 还 不错 ， 味道 还 不错 。 。 。 。 。 。 。 。 。 。 。 。 。 。 ...
#
#
#      itemid  label                                             review
# 743     750      0  半年前 在 网站 西关 风情 的 摄影 比赛 上 侥幸 获得 了 一个 一等奖 ， 奖品 是...
#
#
#      itemid  label                                             review
# 744     751      0  呢 间 最 好吃 的 ， 有 D 58 味 ， 好好 味 ， 够 钁 气 都 看不到 ， 呃...
#
#
#      itemid  label                                             review
# 745     752      0  看 了 点评 网 的 试食 啊 ， 这次 看 了 一圈 ， 所以 特意 挑 了 几样 试食 ...

# %%
df.groupby(by=['column_A'])

# %%
group
